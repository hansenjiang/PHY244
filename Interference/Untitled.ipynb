# %%
import numpy as np
from matplotlib import pyplot as plt

#650 nm

# %%
double = np.loadtxt('data/008a25ddoubleslit4gain100.txt', skiprows=2)

plt.plot(-double[:,0], double[:,1], linewidth=0.5)
plt.show()
